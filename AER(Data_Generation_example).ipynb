# %%
import csv
import librosa
import os
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.preprocessing import StandardScaler

# %%
root_dir=r"C:\Users\akansh\Downloads\a_speech"

# %%
for actor_dir in os.listdir(root_dir):
    actor_name=os.path.join(root_dir,actor_dir)
    my=os.listdir(actor_name)

# %%
print(len(my))
# Out:
# 60

# %%
emotion_file=open('new_emotion.csv','w')

# %%
labels=[]
for actor_dir in os.listdir(root_dir):
    for filename in my:
        print(filename)
        labels.append(filename[6:8])
# Out:
# 03-01-01-01-01-01-24.wav
# 03-01-01-01-01-02-24.wav
# 03-01-01-01-02-01-24.wav
# 03-01-01-01-02-02-24.wav
# 03-01-02-01-01-01-24.wav
# 03-01-02-01-01-02-24.wav
# 03-01-02-01-02-01-24.wav
# 03-01-02-01-02-02-24.wav
# 03-01-02-02-01-01-24.wav
# 03-01-02-02-01-02-24.wav
# 03-01-02-02-02-01-24.wav
# 03-01-02-02-02-02-24.wav
# 03-01-03-01-01-01-24.wav
# 03-01-03-01-01-02-24.wav
# 03-01-03-01-02-01-24.wav
# 03-01-03-01-02-02-24.wav
# 03-01-03-02-01-01-24.wav
# 03-01-03-02-01-02-24.wav
# 03-01-03-02-02-01-24.wav
# 03-01-03-02-02-02-24.wav
# 03-01-04-01-01-01-24.wav
# 03-01-04-01-01-02-24.wav
# 03-01-04-01-02-01-24.wav
# 03-01-04-01-02-02-24.wav
# 03-01-04-02-01-01-24.wav
# 03-01-04-02-01-02-24.wav
# 03-01-04-02-02-01-24.wav
# 03-01-04-02-02-02-24.wav
# 03-01-05-01-01-01-24.wav
# 03-01-05-01-01-02-24.wav
# 03-01-05-01-02-01-24.wav
# 03-01-05-01-02-02-24.wav
# 03-01-05-02-01-01-24.wav
# 03-01-05-02-01-02-24.wav
# 03-01-05-02-02-01-24.wav
# 03-01-05-02-02-02-24.wav
# 03-01-06-01-01-01-24.wav
# ...

# %%
print(len(labels))
print(len(my))
# Out:
# 1440
# 60

# %%
header='name label emotion chroma_stft_mean rmse_mean spec_cent_mean spec_bw_mean rolloff_mean zcr_mean'
for i in range(1, 21):
    header += f' mfcc{i}'
header = header.split()

# %%
emotion='neutral calm happy sad angry fearful disgust surprised'.split()

# %%
header
# Out:
# ['name',
#  'label',
#  'emotion',
#  'chroma_stft_mean',
#  'rmse_mean',
#  'spec_cent_mean',
#  'spec_bw_mean',
#  'rolloff_mean',
#  'zcr_mean',
#  'mfcc1',
#  'mfcc2',
#  'mfcc3',
#  'mfcc4',
#  'mfcc5',
#  'mfcc6',
#  'mfcc7',
#  'mfcc8',
#  'mfcc9',
#  'mfcc10',
#  'mfcc11',
#  'mfcc12',
#  'mfcc13',
#  'mfcc14',
#  'mfcc15',
#  'mfcc16',
#  'mfcc17',
#  'mfcc18',
#  'mfcc19',
#  'mfcc20']

# %%
#emotion[d]

# %%
#d=int(labels[50])

# %%
mfcc_mean=[]
with emotion_file:
    writer=csv.writer(emotion_file)
    writer.writerow(header)
    for actor_dir in os.listdir(root_dir):
        actor_name=os.path.join(root_dir,actor_dir)
        my=os.listdir(actor_name) 
        for i in range(len(my)): 
            songname = os.path.join(actor_name,my[i])
            y, sr = librosa.load(songname)
            
            chroma_stft = librosa.feature.chroma_stft(y=y, sr=sr)
            chroma_stft_mean=np.mean(chroma_stft)
            rmse = librosa.feature.rmse(y=y)
            rmse_mean=np.mean(rmse)
            spec_cent = librosa.feature.spectral_centroid(y=y, sr=sr)
            spec_cent_mean=np.mean(spec_cent)
            spec_bw = librosa.feature.spectral_bandwidth(y=y, sr=sr)
            spec_bw_mean=np.mean(spec_bw)
            rolloff = librosa.feature.spectral_rolloff(y=y, sr=sr)
            rolloff_mean=np.mean(rolloff)
            zcr = librosa.feature.zero_crossing_rate(y)
            zcr_mean=np.mean(zcr)
            final_list=[my[i],labels[i],emotion[int(labels[i])-1],chroma_stft_mean,rmse_mean,spec_cent_mean,spec_bw_mean,rolloff_mean,zcr_mean]
            mfcc = librosa.feature.mfcc(y=y, sr=sr)
            mfcc_mean=[]
            for e in mfcc[0:20]:
                final_list.append(np.mean(e))
            #writer.writerow(my[0:3])
            
            writer.writerow(final_list)
            #writer.writerow(my[2])

# %%
mfcc_mean
# Out:
# [-687.6178194185243,
#  41.894487593220596,
#  -12.930823080191246,
#  2.1811837594238734,
#  -8.68205566476878,
#  -9.392159668562556,
#  -10.734763578937578,
#  -12.707962536289235,
#  -8.536163718597022,
#  -5.35507933917479,
#  -10.244439166935871,
#  -2.972647932326213,
#  -5.9619147505846675,
#  -6.524814022473153,
#  -3.302939427281445,
#  -5.469425150685717,
#  -5.664127770530423,
#  -4.221496230601739,
#  -4.930833317974151,
#  -4.230703500373884]

# %%
data=pd.read_csv('new_emotion.csv')

# %%
data
# Out:
#                           name  label    emotion  chroma_stft_mean  rmse_mean  \
# 0     03-01-01-01-01-01-01.wav      1    neutral          0.598800   0.002257
# 1     03-01-01-01-01-02-01.wav      1    neutral          0.578452   0.002420
# 2     03-01-01-01-02-01-01.wav      1    neutral          0.587585   0.002810
# 3     03-01-01-01-02-02-01.wav      1    neutral          0.573247   0.002618
# 4     03-01-02-01-01-01-01.wav      2       calm          0.561084   0.001654
# ...                        ...    ...        ...               ...        ...
# 1435  03-01-08-01-02-02-24.wav      8  surprised          0.411881   0.007608
# 1436  03-01-08-02-01-01-24.wav      8  surprised          0.449427   0.011720
# 1437  03-01-08-02-01-02-24.wav      8  surprised          0.400250   0.010105
# 1438  03-01-08-02-02-01-24.wav      8  surprised          0.430157   0.013714
# 1439  03-01-08-02-02-02-24.wav      8  surprised          0.478397   0.012621
#
# ...

# %%
#my[5]

# %%
#for i in range(len(my)):
 #   songname = os.path.join(root_dir,my[i])
  #  y, sr = librosa.load(songname)
  #  mfcc = librosa.feature.mfcc(y=y, sr=sr)
  #  mfcc_mean=np.mean(mfcc)
  #  chroma_stft = librosa.feature.chroma_stft(y=y, sr=sr)
   # chroma_stft_mean=np.mean(chroma_stft)
   # rmse = librosa.feature.rmse(y=y)
    #rmse_mean=np.mean(rmse)
    #spec_cent = librosa.feature.spectral_centroid(y=y, sr=sr)
    #spec_cent_mean=np.mean(spec_cent)
    #spec_bw = librosa.feature.spectral_bandwidth(y=y, sr=sr)
    #spec_bw_mean=np.mean(spec_bw)
    #rolloff = librosa.feature.spectral_rolloff(y=y, sr=sr)
    #rolloff_mean=np.mean(rolloff)
    #zcr = librosa.feature.zero_crossing_rate(y)
    #zcr_mean=np.mean(zcr)

# %%
mfcc = librosa.feature.mfcc(y=y, sr=sr)

# %%
#mfcc.shape

# %%
header1='1 2 '

# %%
for i in range(1, 21):
    header1 += f' mfcc{i}'
header1 = header1.split()

# %%
header1
# Out:
# ['1',
#  '2',
#  'mfcc1',
#  'mfcc2',
#  'mfcc3',
#  'mfcc4',
#  'mfcc5',
#  'mfcc6',
#  'mfcc7',
#  'mfcc8',
#  'mfcc9',
#  'mfcc10',
#  'mfcc11',
#  'mfcc12',
#  'mfcc13',
#  'mfcc14',
#  'mfcc15',
#  'mfcc16',
#  'mfcc17',
#  'mfcc18',
#  'mfcc19',
#  'mfcc20']

# %%
mfc_me=[]
for e in mfcc[0:20]:
    mfc_me.append(np.mean(e))

# %%
type(mfc_me)
# Out:
# list

# %%
file=open('trial.csv','w')

# %%
with file:
    writer=csv.writer(file)
    writer.writerow(header1)
    writer.writerow('akansh','gupta',mfc_me)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-165-82dbf3c1df72> in <module>
#       2     writer=csv.writer(file)
#       3     writer.writerow(header1)
# ----> 4     writer.writerow('akansh','gupta',mfc_me)
#
# TypeError: writerow() takes exactly one argument (3 given)

# %%
my=pd.read_csv('trial.csv')

# %%
my
# Out:
#             1          2      mfcc1     mfcc2     mfcc3    mfcc4      mfcc5  \
# 0 -687.617819  41.894488 -12.930823  2.181184 -8.682056 -9.39216 -10.734764
#
#        mfcc6     mfcc7     mfcc8  ...    mfcc11    mfcc12    mfcc13    mfcc14  \
# 0 -12.707963 -8.536164 -5.355079  ... -5.961915 -6.524814 -3.302939 -5.469425
#
#      mfcc15    mfcc16    mfcc17    mfcc18  mfcc19  mfcc20
# 0 -5.664128 -4.221496 -4.930833 -4.230704     NaN     NaN
#
# [1 rows x 22 columns]

# %%
np.mean(mfcc[1])
# Out:
# 30.043263915094776

# %%
#np.mean(mfcc[19])

# %%
#rmse = librosa.feature.rmse(y=)

# %%
#rmse.shape

# %%
#data1=data

# %%
#data1.head()

# %%
#data1['file-name']

# %%
#data.drop(columns=['file-name'],inplace=True)

# %%
#data.head()

# %%
#data1.head()

# %%
data_copy=data.copy()

# %%
data_copy.head()
# Out:
#                        name  label  emotion  chroma_stft_mean  rmse_mean  \
# 0  03-01-01-01-01-01-01.wav      1  neutral          0.598800   0.002257
# 1  03-01-01-01-01-02-01.wav      1  neutral          0.578452   0.002420
# 2  03-01-01-01-02-01-01.wav      1  neutral          0.587585   0.002810
# 3  03-01-01-01-02-02-01.wav      1  neutral          0.573247   0.002618
# 4  03-01-02-01-01-01-01.wav      2     calm          0.561084   0.001654
#
#    spec_cent_mean  spec_bw_mean  rolloff_mean  zcr_mean       mfcc1  ...  \
# 0     3435.943088   2600.929791   6264.656291  0.326237 -697.984245  ...
# 1     3231.037280   2646.981271   6162.832642  0.340786 -693.069755  ...
# 2     3203.154528   2605.181241   6117.338659  0.356861 -691.770194  ...
# 3     3080.483081   2644.191743   6094.210838  0.366200 -685.237871  ...
# 4     3192.620354   2601.322629   6003.471105  0.313122 -727.317945  ...
#
#      mfcc11    mfcc12    mfcc13    mfcc14    mfcc15    mfcc16    mfcc17  \
# ...

# %%
#data_copy['Label']=data_copy['label']

# %%
data_copy.head()
# Out:
#                        name  label  emotion  chroma_stft_mean  rmse_mean  \
# 0  03-01-01-01-01-01-01.wav      1  neutral          0.598800   0.002257
# 1  03-01-01-01-01-02-01.wav      1  neutral          0.578452   0.002420
# 2  03-01-01-01-02-01-01.wav      1  neutral          0.587585   0.002810
# 3  03-01-01-01-02-02-01.wav      1  neutral          0.573247   0.002618
# 4  03-01-02-01-01-01-01.wav      2     calm          0.561084   0.001654
#
#    spec_cent_mean  spec_bw_mean  rolloff_mean  zcr_mean       mfcc1  ...  \
# 0     3435.943088   2600.929791   6264.656291  0.326237 -697.984245  ...
# 1     3231.037280   2646.981271   6162.832642  0.340786 -693.069755  ...
# 2     3203.154528   2605.181241   6117.338659  0.356861 -691.770194  ...
# 3     3080.483081   2644.191743   6094.210838  0.366200 -685.237871  ...
# 4     3192.620354   2601.322629   6003.471105  0.313122 -727.317945  ...
#
#      mfcc11    mfcc12    mfcc13    mfcc14    mfcc15    mfcc16    mfcc17  \
# ...

# %%
data.head()
# Out:
#                        name  label  emotion  mfcc_mean  chroma_stft_mean  \
# 0  03-01-01-01-01-01-01.wav      1  neutral -32.629725          0.598800
# 1  03-01-01-01-01-02-01.wav      1  neutral -32.225423          0.578452
# 2  03-01-01-01-02-01-01.wav      1  neutral -32.368660          0.587585
# 3  03-01-01-01-02-02-01.wav      1  neutral -31.704132          0.573247
# 4  03-01-02-01-01-01-01.wav      2     calm -33.520944          0.561084
#
#    rmse_mean  spec_cent_mean  spec_bw_mean  rolloff_mean  zcr_mean
# 0   0.002257     3435.943088   2600.929791   6264.656291  0.326237
# 1   0.002420     3231.037280   2646.981271   6162.832642  0.340786
# 2   0.002810     3203.154528   2605.181241   6117.338659  0.356861
# 3   0.002618     3080.483081   2644.191743   6094.210838  0.366200
# 4   0.001654     3192.620354   2601.322629   6003.471105  0.313122

# %%
#data_copy.drop(columns=['label','Label'],inplace=True)

# %%
data_copy.drop(columns=['name','emotion','label'],inplace=True)

# %%
data_copy.head()
# Out:
#    chroma_stft_mean  rmse_mean  spec_cent_mean  spec_bw_mean  rolloff_mean  \
# 0          0.598800   0.002257     3435.943088   2600.929791   6264.656291
# 1          0.578452   0.002420     3231.037280   2646.981271   6162.832642
# 2          0.587585   0.002810     3203.154528   2605.181241   6117.338659
# 3          0.573247   0.002618     3080.483081   2644.191743   6094.210838
# 4          0.561084   0.001654     3192.620354   2601.322629   6003.471105
#
#    zcr_mean       mfcc1      mfcc2     mfcc3      mfcc4  ...    mfcc11  \
# 0  0.326237 -697.984245  55.228483  0.323863  12.775377  ...  0.496104
# 1  0.340786 -693.069755  55.734569 -1.919739  16.408997  ...  0.494107
# 2  0.356861 -691.770194  58.350647 -0.165160  13.952124  ...  0.264550
# 3  0.366200 -685.237871  56.236698  2.453112  13.566656  ...  0.895644
# 4  0.313122 -727.317945  62.764397  2.751275  15.473257  ...  0.639895
#
#      mfcc12    mfcc13    mfcc14    mfcc15    mfcc16    mfcc17    mfcc18  \
# ...

# %%
scaler = StandardScaler()
x= scaler.fit_transform(np.array(data_copy.iloc[:, :-1], dtype = float))

# %%
pd.DataFrame(x)
# Out:
#             0         1         2         3         4         5         6   \
# 0     1.871032 -0.640094  1.594417  0.518365  1.268024  1.331498 -1.076004
# 1     1.565089 -0.627500  1.014335  0.720158  1.089064  1.556114 -1.027763
# 2     1.702408 -0.597266  0.935400  0.536995  1.009107  1.804270 -1.015006
# 3     1.486822 -0.612147  0.588121  0.707934  0.968458  1.948450 -0.950885
# 4     1.303950 -0.686764  0.905578  0.520087  0.808979  1.129038 -1.363945
# ...        ...       ...       ...       ...       ...       ...       ...
# 1435 -0.939381 -0.225984  0.249415 -0.886966 -0.153944  0.951389  0.015754
# 1436 -0.374862  0.092264  0.477565 -0.650234  0.010971  0.468632  0.545872
# 1437 -1.114247 -0.032691  0.406886 -0.975490 -0.236220  0.551361  0.459562
# 1438 -0.664588  0.246605  0.923335 -0.119927  0.721672 -0.052095  0.936272
# 1439  0.060718  0.161975  0.386075 -0.145288  0.179417  0.124842  0.687848
#
# ...
